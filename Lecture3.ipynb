# %% [markdown]
# <a href="https://colab.research.google.com/github/tskmr/Reliability/blob/main/Lecture3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x <- rnorm(1000000, 0, 1)
hist(x)
# Out:
# Plot with title “Histogram of x”

# %%
x <- rweibull(n=10000, scale=1.5, shape=2)
hist(x)
# Out:
# Plot with title “Histogram of x”

# %%
?rweibull

# %%
library(tidyverse)
data.frame(x) %>% ggplot(aes(x)) + geom_histogram(col="white", bins=30)
# Out:
# plot without title

# %%
library(tidyverse)
t = seq(0, 3, len=100)
cdf = 1 - exp(-t^(1.7))
d_cdf = data.frame(func = "cdf", t, y=cdf)
d_cdf %>% ggplot() + geom_point(aes(t, y))
# Out:
# plot without title

# %%
pdf = 1.7 * t^(0.7) * exp(-t^(1.7))
d_pdf = data.frame(func = "pdf", t, y=pdf)
d_pdf %>% ggplot() + geom_point(aes(t, y))
# Out:
# plot without title

# %%
sf = 1-cdf
d_sf = data.frame(func = "sf", t, y=sf)
d_sf %>% ggplot() + geom_point(aes(t, y))
# Out:
# plot without title

# %%
hf = pdf/sf
d_hf = data.frame(func = "hf", t, y=hf)
d_hf %>% ggplot() + geom_point(aes(t, y))
# Out:
# plot without title

# %%
library(tidyverse)
t = seq(0, 8, len=100)
beta = 1.5
eta = 3

cdf = 1 - exp(-(t/eta)^(beta))
d_cdf = data.frame(func = "cdf", t, y=cdf)
d_cdf %>% ggplot() + geom_point(aes(t, y))

pdf = beta/eta * (t/eta)^(beta-1) * exp(-(t/eta)^(beta))
d_pdf = data.frame(func = "pdf", t, y=pdf)
d_pdf %>% ggplot() + geom_point(aes(t, y))

sf = 1-cdf
d_sf = data.frame(func = "sf", t, y=sf)
d_sf %>% ggplot() + geom_point(aes(t, y))

hf = pdf/sf
d_hf = data.frame(func = "hf", t, y=hf)
d_hf %>% ggplot() + geom_point(aes(t, y))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
u = runif(10000)
m = 2
eta = 3
x = eta*(-log(1-u))^(1/m)
data.frame(x) %>% ggplot() + geom_histogram(aes(x), col="white", fill = "skyblue")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
u = runif(20)
m = 2
eta = 3
x = eta*(-log(1-u))^(1/m)
data.frame(x) %>% ggplot() + geom_histogram(aes(x, ..density.. ), col="white", fill = "skyblue") + 
  stat_function(fun = dweibull, args = list(shape=m, scale=eta))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
